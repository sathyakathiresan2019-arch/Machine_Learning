# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalized_model_Random_Forest.sav",'rb'))
result=loaded_model.predict([[35,26.05,1,0,0]])

# %%
result
# Out:
# array([15860.7553936])
