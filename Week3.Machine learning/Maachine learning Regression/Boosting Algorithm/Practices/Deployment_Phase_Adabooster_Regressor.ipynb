# %%
import pickle
import pandas as pd

# %%
loaded_model = pickle.load(open('adaboost_model.sav', 'rb'))

# %%
new_data = pd.DataFrame({
    'R&D Spend': [15000],
    'Administration': [12000],
    'Marketing Spend': [3000],
    'State': ['New York']
})

# %%
prediction = loaded_model.predict(new_data)

# %%
print("Predicted Profit =", prediction[0])
# Out:
# Predicted Profit = 108169.47333333333
