# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
Independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(Independent,dependent,test_size=0.30,random_state=0)

# %%
x_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]],
#       shape=(936, 5))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'C':[10,100,1000,2000,3000],'gamma':['auto','scale'],'kernel':['rbf','poly','sigmoid','linear']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\SPPSS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("R_score value for the best parameter {}:".format(grid.best_params_))
# Out:
# R_score value for the best parameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.088678      0.009874         0.034611        0.003163       10
# 1        0.065688      0.007512         0.012355        0.001445       10
# 2        0.088494      0.007096         0.016482        0.002748       10
# 3        0.078260      0.026190         0.013439        0.002258       10
# 4        0.090142      0.004159         0.034701        0.001880       10
# 5        0.066064      0.002632         0.012847        0.001471       10
# 6        0.092286      0.013545         0.019769        0.002521       10
# 7        0.065382      0.005743         0.012446        0.001154       10
# 8        0.079675      0.005247         0.037048        0.004078      100
# 9        0.081649      0.001268         0.011396        0.001160      100
# 10       0.087424      0.007763         0.016616        0.002576      100
# 11       0.073855      0.010522         0.010693        0.001633      100
# ...

# %%
age_input = float(input("age: "))
bmi_input = float(input("bmi: "))
children_input = float(input("children: "))
sex_male_input=int(input("sex_male 0 or 1:"))
smoker_yes_input=int(input("smoker_yes 0 or 1:"))
# Out:
# age:  32
# bmi:  43
# children:  2
# sex_male 0 or 1: 0
# smoker_yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[2291197.32936186]

# %%
result=pd.DataFrame({'Actual':x_test.ravel,
   
    'Predicted': Future_Prediction.flatten() if hasattr(Future_Prediction, 'flatten') else Future_Prediction
})

# %%
print(result)
# Out:
#                                               Actual     Predicted
# 0  <built-in method ravel of numpy.ndarray object...  2.291197e+06
