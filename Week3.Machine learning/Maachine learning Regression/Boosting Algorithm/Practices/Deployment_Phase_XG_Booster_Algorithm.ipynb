# %%
import pickle
import pandas as pd

model = pickle.load(open('xgboost_model.sav', 'rb'))

test_data = pd.DataFrame({
    'R&D Spend':[150000],
    'Administration':[120000],
    'Marketing Spend':[350000],
    'State':['New York']
})

profit = model.predict(test_data)

print("Predicted Profit =", profit[0])
# Out:
# Predicted Profit = 182885.53
