# %%
import pandas as pd

# %%
dataset= pd.read_csv("50_Startups.csv")

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156994.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.85        311613.28    New York  152211.77
# 9    94657.16       145077.58        282574.31    New York  125370.37
# 10   91749.16       114175.79        294919.57     Florida  124266.90
# 11   86419.70       153514.11             0.00    New York  122776.86
# ...

# %%
dataset=pd.get_dummies(dataset,dtype=int ,drop_first=True)
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156994.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.85        311613.28  152211.77              0
# 9    94657.16       145077.58        282574.31  125370.37              0
# 10   91749.16       114175.79        294919.57  124266.90              1
# 11   86419.70       153514.11             0.00  122776.86              0
# ...

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156994.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.85        311613.28  152211.77              0
# 9    94657.16       145077.58        282574.31  125370.37              0
# 10   91749.16       114175.79        294919.57  124266.90              1
# 11   86419.70       153514.11             0.00  122776.86              0
# ...

# %%
Independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend',
       'State_Florida', 'State_New York']]

# %%
dependent=dataset[["Profit"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(Independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(Independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[ 8.16029499e-01, -2.66251940e-02,  2.48098075e-02,
#         -6.00909531e+03, -1.67381282e+03]])

# %%
bias=regressor.intercept_
bias
# Out:
# array([51563.56193681])

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.944950082092763

# %%
import pickle 
filename="Finalized_model_mul_linear.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Finalized_model_mul_linear.sav",'rb'))
result=loaded_model.predict([[1453,4535,485,0,1]])
# Out:
# C:\Users\SPPSS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[50966.72747948]])

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(X_test, y_test)
plt.show()

# %%
#DataFrame creates a table-like structure with rows and columns.
result1 = pd.DataFrame({
    #iloc means integer-location based indexing.
    'Actual': y_test.iloc[:, 0],  # 0 means first column of y_test.
    #This line handles different shapes of prediction output.hasattr() checks whether an object contains a specific attribute or method.Many machine learning models return predictions as a 2D array.
    'Predicted': y_pred.flatten() if hasattr(y_pred, 'flatten') else y_pred #y_pred, 'flatten'-Convert a 2D array into a 1D array
})

print(result1)
# Out:
#        Actual      Predicted
# 2   191050.39  178195.022731
# 20  111313.02  117200.046132
# 14  110352.25  110192.388289
# 17  124266.90  124701.432928
# 5   156994.12  163850.124271
# 11  122776.86  116323.430692
# 22  108733.99  105408.615103
# 13  111313.02  117200.046132
