# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#        User ID  Age  Estimated  Purchased  Gender_Male
# 0   15624510.0   19      19000          0            1
# 1   15650010.0   35      20000          0            1
# 2   15586243.0   26      43000          0            0
# 3   15326200.0   27      57000          0            0
# 4   16235420.0   35      76000          0            1
# 5   16574200.0   26      58000          0            1
# 6   15368462.0   24      84000          0            0
# 7   15479532.0   28     150000          1            0
# 8   15865243.0   40      33000          0            1
# 9   15486325.0   25      65000          0            0
# 10  15846729.0   20      80000          0            0
# 11  16258436.0   23      52000          1            0
# 12  16583235.0   28      82000          1            1
# 13  16842356.0   35      20000          0            1
# 14  15846253.0   34      25000          0            0
# 15  15765232.0   29      32000          0            0
# 16  15846723.0   37      55000          0            0
# 17  15952423.0   42      62000          0            1
# 18  15959559.0   50      58000          1            1
# 19  16250000.0   45      75220          0            1
# 20  16351571.0   28      82100          0            0
# 21  16500359.5   42     160000          1            1
# 22  16649148.0   35      25000          0            0
# 23  16797936.5   32      65010          0            0
# 24  16946725.0   48      35000          0            0
# 25  17095513.5   22      90000          1            1
# 26  17244302.0   27      75130          0            1
# 27  17393090.5   28      36000          0            1
# 28  17541879.0   35      45000          1            0
# 29  17690667.5   36      75500          0            1
# 30  17839456.0   40      83000          1            0
# 31  17988244.5   37      15000          1            1

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    23
# 1     9
# Name: count, dtype: int64

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset.columns
# Out:
# Index(['Age', 'Estimated', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Ind=dataset[['Age', 'Estimated','Gender_Male']]

# %%
dep=dataset[[ 'Purchased']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(Ind,dep,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
Classifier=RandomForestClassifier(n_estimators=50,random_state=0)
Classifier.fit(x_train,y_train)
# Out:
# C:\Users\SPPSS\anaconda3\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
y_pred=Classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[7 1]
#  [2 0]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82         8
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.70        10
#    macro avg       0.39      0.44      0.41        10
# weighted avg       0.62      0.70      0.66        10
